# %%
reading_girl = []
f = open('StudentsPerformance.csv')
for line in f:
    values = line.split(',')
    if values[0] == '"gender"'or values[0] == '"male"':
        continue
    else:
        mark_girl = int(values[6][1:-1])
        reading_girl.append(mark_girl)
        
reading_girl
# Out:
# [72,
#  90,
#  95,
#  83,
#  95,
#  60,
#  81,
#  53,
#  75,
#  32,
#  58,
#  75,
#  73,
#  69,
#  70,
#  74,
#  65,
#  72,
#  81,
#  64,
#  90,
#  73,
#  58,
#  56,
#  65,
#  71,
#  74,
#  84,
#  41,
#  85,
#  17,
#  80,
#  58,
#  72,
#  64,
#  63,
#  51,
#  74,
#  68,
#  49,
#  80,
#  83,
#  71,
#  70,
#  86,
#  72,
#  86,
#  72,
#  67,
#  67,
#  91,
#  67,
#  100,
#  76,
#  64,
#  89,
#  58,
#  100,
#  85,
#  82,
#  63,
#  69,
#  92,
#  93,
#  95,
#  49,
#  81,
#  66,
#  72,
#  62,
#  55,
#  39,
#  75,
#  70,
#  89,
#  74,
#  86,
#  88,
#  92,
#  100,
#  76,
#  83,
#  75,
#  86,
#  67,
#  51,
#  91,
#  54,
#  77,
#  70,
#  100,
#  64,
#  50,
#  69,
#  88,
#  65,
#  64,
#  84,
#  53,
#  79,
#  84,
#  81,
#  69,
#  81,
#  61,
#  62,
#  86,
#  42,
#  68,
#  65,
#  66,
#  56,
#  72,
#  95,
#  86,
#  60,
#  83,
#  52,
#  70,
#  64,
#  83,
#  70,
#  73,
#  73,
#  75,
#  81,
#  79,
#  50,
#  93,
#  75,
#  72,
#  92,
#  76,
#  53,
#  70,
#  92,
#  63,
#  86,
#  79,
#  78,
#  46,
#  89,
# ...
